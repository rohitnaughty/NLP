# %% [markdown]
# 1. What are Sequence-to-sequence models?

# %% [markdown]
# Sequence to sequence (often abbreviated to seq2seq) models is a special class of Recurrent Neural Network
# architectures that we typically use (but not restricted) to solve complex Language problem like Machine Translation,
# Question Answering, creating Chatbots, Text summerization, etc.

# %% [markdown]
# ![image.png](attachment:4c9ecf75-0864-4197-bade-b02a4a674f17.png)

# %% [markdown]
# Use Cases of the Sequence to Sequence Models: Sequence to sequence models lies behind numerous systems that you face on a
# daily basis. For instance, seq2seq model powers applications like Google Translate, voice-enabled devices, and online
# chatbots.
#
# The following are some of the applications:
#
#     Machine translation- A 2016 paper from Google shows how the seq2seq model's translation quantity "approaches or surpasses all current published results".

# %% [markdown]
# ![image.png](attachment:0966219e-16ab-43cd-91c5-394b4dc67730.png)

# %% [markdown]
# Speech recognition-another Google paper that compares the existing seq2seq models on the speech recognition task.

# %% [markdown]
# ![image.png](attachment:ebce9733-e100-49a6-bcd8-ae601526615f.png)

# %% [markdown]
# These are only some applications where seq2seq is seen as the best solution.This model can be used as a  solution to any
# sequence-based problem, especially ones where the inputs and outputs have different sizes and categories.

# %% [markdown]
# 2. What are the Problem with Vanilla RNNs?

# %% [markdown]
# RNNs suffer from the problem of vanishing gradients, Which hampers learning of long  data sequences.The gradients carry information used in the RNN parameter
# update and when the gradient becomes smaller and smaller, the parameter updates become insignificant which no real learning is done.

# %% [markdown]
# 3. What is Gradient clipping?

# %% [markdown]
# Gradient clipping is a technique to prevent exploding gradients is very deep networks, usually in recurrent neural networks.A neural network is a learning
# algorithum, also called neural network or neural net, that uses a network of functions to understand and translate data input into a specific output.
#
# This type of learning algorithum is designed based on the way neurons function in the human brain.There are many ways to compute gradient clipping , but a common
# one is to rescale gradients so that their normis at most a perticular value. With gradient clipping, pre-determined gradient threshold be introduced, and thus
# gradients norms that exceed this threshold are scaled down to match the norm. This prevents any gradient to have norm greater than the threshold and thus the
# gradients are clipping.There is an introduced bias in the resulting values from the gradient, but gradient clipping can keep things stable.

# %% [markdown]
# 4. Explain Attention mechanism

# %% [markdown]
# The attention mechanism was introduced to improve the performance of the encoder-decoder model foe machine
# translation.The idea behind the attention mechanism was to permit the decoder to utilize the most relevent parts of the
# input sequence in a flexible manner, by a weighted combination of all of the encoded input vectors, with the most
# relevant vectors being attributed the highest weights.
#
# The attention mechanism was introduced by Bahdanau et al. (2014), to address the bottleneck problem that arise with the
# use of a fixed-length encoding vector, where the decoder would have limited access to the information provided by the input.
# This is through to become especially problematic for long and/or complex sequences, where the dimensionality of
# their representation would be forced to be the same as for shorter or simpler sequences.

# %% [markdown]
# 5. Explain Conditional random fields (CRFs)

# %% [markdown]
# Conditional random fields (CRFs) are a class of statistical modeling methods often applied in pattern recognition
# and machine learing and used for structured prediction. Whereas a classifier predicts a lable for a single sample
# without considering "neighbouring" samples, a CRF can take context into account.

# %% [markdown]
# 6. Explain self-attention

# %% [markdown]
# Self Attention, also called intra Attention, is a attention mechanism relating different positions of a single
# sequence in order to compute a representation of the same sequence.It has been shown to be very useful in machine
# reading, abstractive summarization, or image description generation.

# %% [markdown]
# 7. What is Bahdanau Attention?

# %% [markdown]
# Conventional encoder-decoder architectures for machine translation encoder every source sentence into a fixed-length
# vector, irrespective of its length, from which the decoder would then generate a translation.This made it difficult for
# the neural network to cope with long sentence, essentially resulting in a perforance bottelneck.
# The Bahdanau attention was proposed to address the performance bottleneck of concentional encoder-decoder architectures,
# achieving significant improvements over the conventional approach.
#
# The Bahdanau attention machianism has inherited its name from the first author of the paper in which it was published.
#
# It follows the work of Cho et al.(2014) and sutskever el al. (2014), who had also employed an RNN encoder-decoder
# framework for neural machine translation, speciifically by encoding a variable-length source sentence into a fixed-length
# vector. The latter would then be decoded into a variable-length target sentence.
#
# Bahdanau el al. (2014) argue that this encoding of a variable-length input into a fixed-length vector squashes the
# information of the source sentence, irrespective of its length, causing the performance of a basic enncoder-decoder model
# to deteriorate rapidly with an increasing length of the input sentence .The approach they propose, on the other hand ,
# relpaces the fixed-length vector with a variable-length one, to improve the translation performance os the basic encoder
# decoder model.

# %% [markdown]
# 8. What is a Language Model?

# %% [markdown]
# Language modeling (LM) is the use of various statistical and probabilistic techniques to determine the probability of a given sequence of words occuring in a sentence.Language models analyze bodies of text data to provide a basic for their
# word predictions. They are used in natural language processing (NLP) applications, particularly ones that generate
# text as an output. Some of the applications include, machine translation and question answering.

# %% [markdown]
# 9. What is Multi-Head Attention?

# %% [markdown]
# Multi-head Attention is  a module for attention mechanisms which runs through an attention machanism several times in parallel. The independent attention
# output are then concatenated and linearly transformed into the expected dimension. Intuitively, multiple attention heads allows for attending to parts of the
# sequence differently (e.g.longer-term dependencies versus shorter-term dependencies).

# %% [markdown]
# ![image.png](attachment:1473d070-c61f-42d0-996d-03c45121a984.png)

# %% [markdown]
# 10. What is Bilingual Evaluation Understudy (BLEU)

# %% [markdown]
# BLEU, or the Bilingual Evaluation Understudy, is a score for comparing a candidate translation of text to one or
# more reference translations.
#
# Although devoloped for translation, it can be used to evaluate text generated for a suite of natural lanuage processing
# tasks.
#
# The Billingual Evaluation Understudy score, or BLEU for short, is  a matric for evaluating a generated sentence to a
# reference sentence.
#
# A perfect match results in a score of 1.0, whereas a perfect mismatch results in a score of 0.0.
#
# The score was devoloped or evaluating the predictions made by automatic machine translation systems. It is not perfect,
# but does offer 5 compelling benifits:
#
#     It is quick and inexpensive to calculate .
#     It is easy to understand.
#     It is language independent.
#     It correlates highly with human evaluation.
#     It has been widely adopted.
